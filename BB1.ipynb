# %%
import tkinter as tk
import tkinter.ttk as ttk
from tkmacosx import Button

from tkinter import messagebox as m_box
import random


#Creating the window
win = tk.Tk()
win.title("Bully Block")
win.geometry("450x700")

win.configure(bg='yellow')

#Create a label saying BullyBlock at 175, 25 with a font size of 40
label1 = tk.Label(win, text="BullyBlock", font=("Arial Bold", 40))
label1.place(x=175, y=25)


win.title("place() method")
win.geometry("450x700")

#Set buttons to fix for window size
win.resizable(False, False)


#Defining the functions
def button1_func():
    m_box.showinfo("Level 1", "Verbal abuse/Mocking")

def button2_func():
    m_box.showinfo("Level 2", "Physical abuse such as shoving")

def button3_func():
    m_box.showinfo("Level 3", "Physical abuse such as getting into fights")

def button4_func():
    m_box.showinfo("Level 4", "Guns/kidnapping")


button1 = Button(win, text="Verbal abuse/Mocking", width=150, bg='yellow', fg='black', activebackground='brown', activeforeground='black', command=button1_func)
button1.place(x=175, y=75)
button2=Button(win, text="Pushing/Shoving", width=150, bg='orange', fg='black', activebackground='brown', activeforeground='black',  command=button2_func)
button2.place(x=175, y=150)
button3=Button(win, text="Fighting", width=150, bg='red', fg='black', activebackground='brown', activeforeground='black', command=button3_func)
button3.place(x=175, y=225)
button4=Button(win, text="Guns/kidnapping", width=150, bg='black', fg='white', activebackground='brown', activeforeground='black', command=button4_func)
button4.place(x=175, y=300)
win.mainloop()



#Calling the functions
button1.config(command = button1_func)
button2.config(command = button2_func)
button3.config(command = button3_func)
button4.config(command = button4_func)

#Running the mainloop
win.mainloop()
button2.place(x=100, y=25)
button3=tk.Button(win, text="button3")
button3.place(x=175, y=100)
button4.place(x=250, y=25)
win.mainloop()


#Defining the functions
def button1_func():
    m_box.showinfo("Level 1", "Verbal abuse/Mocking")

def button2_func():
    m_box.showinfo("Level 2", "Physical abuse such as shoving")

def button3_func():
    m_box.showinfo("Level 3", "Physical abuse such as getting into fights")

def button4_func():
    m_box.showinfo("Level 4", "Guns/kidnapping")


#Calling the functions
button1.config(command = button1_func)
button2.config(command = button2_func)
button3.config(command = button3_func)
button4.config(command = button4_func)

#Running the mainloop
win.mainloop()
# Out:
# ---------------------------------------------------------------------------
# TclError                                  Traceback (most recent call last)
# /Users/shashivelur/Projects/bullyblock/BB1.ipynb Cell 1 line 6
#      <a href='vscode-notebook-cell:/Users/shashivelur/Projects/bullyblock/BB1.ipynb#W1sZmlsZQ%3D%3D?line=57'>58</a> win.mainloop()
#      <a href='vscode-notebook-cell:/Users/shashivelur/Projects/bullyblock/BB1.ipynb#W1sZmlsZQ%3D%3D?line=61'>62</a> #Calling the functions
# ---> <a href='vscode-notebook-cell:/Users/shashivelur/Projects/bullyblock/BB1.ipynb#W1sZmlsZQ%3D%3D?line=62'>63</a> button1.config(command = button1_func)
#      <a href='vscode-notebook-cell:/Users/shashivelur/Projects/bullyblock/BB1.ipynb#W1sZmlsZQ%3D%3D?line=63'>64</a> button2.config(command = button2_func)
#      <a href='vscode-notebook-cell:/Users/shashivelur/Projects/bullyblock/BB1.ipynb#W1sZmlsZQ%3D%3D?line=64'>65</a> button3.config(command = button3_func)
#
# File /usr/local/Cellar/python@3.11/3.11.5/Frameworks/Python.framework/Versions/3.11/lib/python3.11/tkinter/__init__.py:1702, in Misc.configure(self, cnf, **kw)
#    1695 def configure(self, cnf=None, **kw):
#    1696     """Configure resources of a widget.
#    1697
#    1698     The values for resources are specified as keyword
#    1699     arguments. To get an overview about
#    1700     the allowed keyword arguments call the method keys.
#    1701     """
# -> 1702     return self._configure('configure', cnf, kw)
#
# File /usr/local/lib/python3.11/site-packages/tkmacosx/basewidgets/button_base.py:1127, in ButtonBase._configure(self, cmd, cnf, kw)
#    1124     if ((i in BUTTON_FEATURES)
#    1125             or (i == 'radius' and self._type == 'circle')):
#    1126         cnf[i] = kw.pop(i, None)
# -> 1127 _return = _Canvas._configure(self, cmd, None, kw)
#    1128 if kw.get('bg') or kw.get('background'):
#    1129     self._org_bg = self['bg']
#
# File /usr/local/lib/python3.11/site-packages/tkmacosx/utils/colorvar_patches.py:106, in _colorvar_patch_configure.<locals>._patch(self, cmd, cnf, kw)
#     103                     _all_traces_colorvar[(self, (i, tag))] = (
#     104                         var, cbname)
#     105                 tmp_dict[i] = var.get()
# --> 106 return fn(self, cmd, cnf, kw)
#
# File /usr/local/Cellar/python@3.11/3.11.5/Frameworks/Python.framework/Versions/3.11/lib/python3.11/tkinter/__init__.py:1689, in Misc._configure(self, cmd, cnf, kw)
#    1687     cnf = _cnfmerge(cnf)
#    1688 if cnf is None:
# -> 1689     return self._getconfigure(_flatten((self._w, cmd)))
#    1690 if isinstance(cnf, str):
#    1691     return self._getconfigure1(_flatten((self._w, cmd, '-'+cnf)))
#
# File /usr/local/Cellar/python@3.11/3.11.5/Frameworks/Python.framework/Versions/3.11/lib/python3.11/tkinter/__init__.py:1673, in Misc._getconfigure(self, *args)
#    1671 """Call Tcl configure command and return the result as a dict."""
#    1672 cnf = {}
# -> 1673 for x in self.tk.splitlist(self.tk.call(*args)):
#    1674     x = self.tk.splitlist(x)
#    1675     cnf[x[0][1:]] = (x[0][1:],) + x[1:]
#
# TclError: invalid command name ".!button"
