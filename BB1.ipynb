# %%
# Bully Block App

import tkinter as tk
import tkinter.ttk as ttk

# @Shivank - you will need to comment out this line and replace it with "from tk import Button" for running on Windows.
from tkmacosx import Button

from tkinter import messagebox as m_box
import random

#Creating the window
win = tk.Tk()
win.title("Bully Block")
win.geometry("450x700")

win.configure(bg='black')
win.title("Bully Block")
win.geometry("450x700")
#Set buttons to fix for window size
win.resizable(False, False)

#Create a label saying BullyBlock at 175, 25 with a font size of 40
label1 = tk.Label(win, text="BullyBlock", font=("Arial Bold", 40), fg='gray', bg='black')
label1.place(x=150, y=10)

#Defining the functions
def button1_func():
    m_box.showinfo("Level 1", "Verbal abuse/Mocking")

def button2_func():
    m_box.showinfo("Level 2", "Physical abuse such as shoving")

def button3_func():
    m_box.showinfo("Level 3", "Physical abuse such as getting into fights")

def button4_func():
    m_box.showinfo("Level 4", "Guns/kidnapping")


button1 = Button(win, text="Verbal abuse/Mocking", width=150, height=80,  bg='yellow', fg='black', activebackground='brown', activeforeground='black', command=button1_func)
button1.place(x=175, y=75)
button2=Button(win, text="Pushing/Shoving", width=150, height=80, bg='orange', fg='black', activebackground='brown', activeforeground='black',  command=button2_func)
button2.place(x=175, y=150)
button3=Button(win, text="Fighting", width=150, height=80, bg='red', fg='black', activebackground='brown', activeforeground='black', command=button3_func)
button3.place(x=175, y=225)
button4=Button(win, text="Guns/kidnapping", width=150, height=80, bg='black', fg='white', activebackground='brown', activeforeground='black', command=button4_func)
button4.place(x=175, y=300)


#Defining the functions
def button1_func():
    m_box.showinfo("Level 1", "Verbal abuse/Mocking")

def button2_func():
    m_box.showinfo("Level 2", "Physical abuse such as shoving")

def button3_func():
    m_box.showinfo("Level 3", "Physical abuse such as getting into fights")

def button4_func():
    m_box.showinfo("Level 4", "Guns/kidnapping")


#Calling the functions
button1.config(command = button1_func)
button2.config(command = button2_func)
button3.config(command = button3_func)
button4.config(command = button4_func)

#Running the mainloop
win.mainloop()
