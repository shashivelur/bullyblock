# %%
# create an app with 4 buttons
# 1. button1 says "level 1"
# 2. button2 says "level 2"
# 3. button3 says "level 3"
# 4. button4 says "level 4"
# button one is white
# button two is yellow
# button three is orange
# button four is red
# when you click button1, the screen shows a yellow background with the text "mocking"
# when you click button2, the screen shows an orange background with the text "shoving"
# when you click button3, the screen shows a red background with the text "fighting"
# when you click button4, the screen shows a black background with the text "weapons"
# each button is in the spae of a rounded rectangle
# each button has a White border
# each button has a black text
# each button has a black shadow
# the backround of the app is light blue
# the text of the app is black
# the app is called "Bully Block"
# use tkinter




from colour import Color
from tkinter import *
from tkinter import messagebox
import tkinter as tk
import webbrowser
from tkmacosx import Button
# create a tkinter window
root = tk.Tk()
# create a title for the window
root.title("Bully Block")
# create a label for the window
label = tk.Label(root, text="BullyBlock", font=("Arial Bold", 50))
label.grid(column=1, row=0)
# change postion of the label
label.place(x=70, y=20)
# change color of the label
label.config(bg="light grey")
# change color of the text
label.config(fg="black")


# create a function for the buttons
def clicked1():
    messagebox.showinfo("Level 1", "message friends and family")
def clicked2():
    messagebox.showinfo("Level 2", "message friends, family, and teachers")
def clicked3():
    messagebox.showinfo("Level 3", "message friends, family, teachers, and surrounding people")
def clicked4():
    messagebox.showinfo("Level 4", "message friends, family, teachers, surrounding people, and police")
# create a button for the window
button1 = tk.Button(root, text="Mocking", bg="white", fg="gold", command=clicked1)
button1.grid(column=0, row=1)
button2 = tk.Button(root, text="Bullying", bg="white", fg="dark orange", command=clicked2)
button2.grid(column=0, row=2)
button3 = tk.Button(root, text="Fighting", bg="white", fg="brown", command=clicked3)
button3.grid(column=0, row=3)
button4 = tk.Button(root, text="Weapons", bg="white", fg="red", command=clicked4)
button4.grid(column=0, row=4)
# change size of the buttons
button1.config(height=5, width=20)
button2.config(height=5, width=20)
button3.config(height=5, width=20)
button4.config(height=5, width=20)
# change shape of the buttons to rounded rectangle
button1.config(relief="ridge", borderwidth=10)
button2.config(relief="ridge", borderwidth=10)
button3.config(relief="ridge", borderwidth=10)
button4.config(relief="ridge", borderwidth=10)
# change positon of the buttons
button1.place(x=60, y=100)
button2.place(x=60, y=240)
button3.place(x=60, y=380)
button4.place(x=60, y=520)
# bold the text of the buttons
button1.config(font=("Arial Bold", 20))
button2.config(font=("Arial Bold", 20))
button3.config(font=("Arial Bold", 20))
button4.config(font=("Arial Bold", 20))
#change the border color of the buttons
button1.config(highlightbackground="gold")
button2.config(highlightbackground="dark orange")
button3.config(highlightbackground="brown")
button4.config(highlightbackground="red")

#create a button to open a new window to add contacts
def clicked5():
    window = tk.Toplevel(root)
    window.title("Add Contact")
    window.geometry("400x700")
    window.configure(bg="light grey")
    label = tk.Label(window, text="Add Contact", font=("Arial Bold", 50))
    label.grid(column=0, row=0)
    label.place(x=50, y=50)
    label.config(bg="light grey")
    label.config(fg="black")
    name = tk.Label(window, text="First Name", font=("Arial Bold", 20))
    name.grid(column=0, row=1)
    name.place(x=140, y=150)
    name.config(bg="light grey")
    name.config(fg="black")
    phonenumber = tk.Label(window, text="Last Name", font=("Arial Bold", 20))
    phonenumber.grid(column=0, row=2)
    phonenumber.place(x=140, y=250)
    phonenumber.config(bg="light grey")
    phonenumber.config(fg="black")
    email = tk.Label(window, text="Phone Number", font=("Arial Bold", 20))
    email.grid(column=0, row=3)
    email.place(x=125, y=350)
    email.config(bg="light grey")
    email.config(fg="black")
    entry = tk.Entry(window, width=20)
    entry.grid(column=1, row=1)
    entry.place(x=100, y=200)
    entry.config(bg="white")
    entry.config(fg="black")
    entry1 = tk.Entry(window, width=20)
    entry1.grid(column=1, row=2)
    entry1.place(x=100, y=300)
    entry1.config(bg="white")
    entry1.config(fg="black")
    entry2 = tk.Entry(window, width=20)
    entry2.grid(column=1, row=3)
    entry2.place(x=100, y=400)
    entry2.config(bg="white")
    entry2.config(fg="black")
    # create a drop down menu with the options "friends", "family", and "teachers"
    clicked = tk.StringVar()
    clicked.set("Contact Type")
    drop = tk.OptionMenu(window, clicked, "Friend", "Family", "Teacher")
    drop.grid(column=0, row=4)
    drop.place(x=135, y=470)
    drop.config(bg="light grey")
    drop.config(fg="Black")
    # change font size of the drop down menu
    drop.config(font=("Arial Bold", 17))
    # change the color of the drop down menu
    drop.config(bg="white")
    drop.config(fg="black")
    # function to save contact information to a file
    def save_contact(name, phone, email):
        with open('contacts.txt', 'a') as file:
            file.write(f"{name}, {phone}, {email}\n")
    # create a button to save the contact information and drop down bar info
    def save():
        save_contact(entry.get(), entry1.get(), entry2.get())
        save_contact(clicked.get(), "", "")
    button = tk.Button(window, text="Save", bg="white", fg="black", command=save)
    button.grid(column=1, row=5)
    button.place(x=25, y=550)
    button.config(height=1, width=8)
    button.config(relief="ridge", borderwidth=0.1)
    button.config(bg="white")
    button.config(fg="black")
    # create a button to delete all contact information after asking if they are sure
    def delete_all():
        if messagebox.askyesno("Delete All", "Are you sure you want to delete all contacts?"):
            with open('contacts.txt', 'w') as file:
                file.write("")
    button2 = tk.Button(window, text="Delete All", bg="white", fg="black", command=delete_all)
    button2.grid(column=1, row=5)
    button2.place(x=150, y=650)
    button2.config(height=1, width=8)
    button2.config(relief="ridge", borderwidth=0.1)
    button2.config(bg="white")
    button2.config(fg="black")
    # create a button to delete last contact
    def delete_last_entry():
        with open('contacts.txt', 'r') as file:
            lines = file.readlines()
        with open('contacts.txt', 'w') as file:
            file.writelines([item for item in lines[:-1]])
    button3 = tk.Button(window, text="Delete Last Contact", bg="white", fg="black", command=delete_last_entry)
    button3.grid(column=1, row=5)
    button3.place(x=250, y=550)
    button3.config(height=1, width=10)
    button3.config(relief="ridge", borderwidth=0.1)
    button3.config(bg="white")
    button3.config(fg="black")
    # CREATE A BACK BUTTON
    def back():
        window.destroy()
    button4 = tk.Button(window, text="Back", bg="white", fg="black", command=back)
    button4.grid(column=1, row=5)
    button4.place(x=10, y=10)
    button4.config(height=1, width=8)
    button4.config(relief="ridge", borderwidth=0.1)
    button4.config(bg="white")
    entry

# create a button to see the contact information
def see_contacts():
    with open('contacts.txt', 'r') as file:
        messagebox.showinfo("Contacts", file.read())
button1 = tk.Button(root, text="View Contacts", bg="white", fg="black", command=see_contacts)
button1.grid(column=1, row=5)
button1.place(x=300, y=670)
button1.config(height=2, width=7)
button1.config(relief="ridge", borderwidth=0.1)
button1.config(bg="white")
# change text size of the button
button1.config(font=("Arial", 10))
# create a button for the window
button5 = tk.Button(root, text="Add Contacts", bg="white", fg="black", command=clicked5)
# change the text siize of the button
button5.config(font=("Arial", 10))
# change the shape of the button
button5.config(relief="ridge", borderwidth=0.1)
# change the position of the button
button5.place(x=30, y=670)
# change the color of the button
button5.config(bg="white")
# change size of the button
button5.config(height=2, width=7)
# change the background color of the window to light blue
root.configure(bg="light grey")
# change the size of the window
root.geometry("400x700")
# stop creating more windows
root.mainloop()

# end of code
# Out:
# 2023-10-22 14:36:42.880 Python[12884:858904] WARNING: Secure coding is not enabled for restorable state! Enable secure coding by implementing NSApplicationDelegate.applicationSupportsSecureRestorableState: and returning YES.
